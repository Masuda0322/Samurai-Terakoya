# %% [markdown]
# <a href="https://colab.research.google.com/github/Masuda0322/Samurai-Terakoya/blob/main/Untitled1_ipynb_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
upper = 10
lower = 20
hight = 5

# 公式；面積 = (上底+下底)×高さ÷2
area = (upper + lower) * hight / 2

print(area,"cm²")
# Out:
# 75.0 cm²
